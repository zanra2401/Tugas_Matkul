# %% [markdown]
# # Pembersihan Outliers
#
# Secara umum, membersihkan outlier adalah proses mengidentifikasi dan menghapus data yang secara signifikan berbeda dari pola atau distribusi data lain dalam kumpulan data.
#
# **Mengapa Outlier Perlu dibersihkan?**
# - Distorsi Rata-rata: Outlier dapat menarik nilai rata-rata (mean) ke arahnya, membuat nilai tersebut tidak lagi representatif untuk sebagian besar data.
# - Mempengaruhi Model Prediktif: Dalam machine learning, outlier dapat membuat model menjadi kurang akurat. Sebagai contoh, dalam regresi linier, sebuah outlier dapat mengubah garis regresi, mengurangi kemampuan model untuk memprediksi nilai baru dengan tepat.

# %% [markdown]
# ## Data Iris

# %%
from pycaret.anomaly import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pycaret.anomaly import *
#
# ModuleNotFoundError: No module named 'pycaret'

# %%
import pandas as pd
from module.dataTransformer import combineData
from module.fetcher import fetchDataMysql, fetchDataPg

data_pg = fetchDataPg("SELECT petal_length, petal_width, species FROM iris_table")
data_my = fetchDataMysql("SELECT sepal_length, sepal_width FROM iris_table")

iris_df = combineData(data1=data_my, data2=data_pg)
iris_df
# Out:
#     sepal_length sepal_width petal_length petal_width         species
# 0           5.10        3.50         1.40        0.20     Iris-setosa
# 1           4.90        3.00         1.40        0.20     Iris-setosa
# 2           4.70        3.20         1.30        0.20     Iris-setosa
# 3           4.60        3.10         1.50        0.20     Iris-setosa
# 4           5.00        3.60         1.40        0.20     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145         6.70        3.00         5.20        2.30  Iris-virginica
# 146         6.30        2.50         5.00        1.90  Iris-virginica
# 147         6.50        3.00         5.20        2.00  Iris-virginica
# 148         6.20        3.40         5.40        2.30  Iris-virginica
# 149         5.90        3.00         5.10        1.80  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Menyiyngkirkan kolom species (class) 
numeric_iris_df = iris_df[["sepal_length", "sepal_width", "petal_length", "petal_width"]].astype(float)
numeric_iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ## Model ABOD
#
# Membuat model ABOD dengan fraction (proporsi data yang akan di anggap sebagai outlier) sama dengan 0.05 atau 5%

# %%
from pycaret.anomaly import *

s = setup(data=numeric_iris_df)

abod_model = create_model("abod", fraction=0.05)

df_abod = assign_model(abod_model)

df_abod
# Out:
# <style type="text/css">
# #T_dbadd_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_dbadd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbadd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_dbadd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbadd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dbadd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_dbadd_row0_col1" class="data row0 col1" >7108</td>
#     </tr>
#     <tr>
#       <th id="T_dbadd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dbadd_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_dbadd_row1_col1" class="data row1 col1" >(150, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_dbadd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dbadd_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_dbadd_row2_col1" class="data row2 col1" >(150, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_dbadd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dbadd_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_dbadd_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_dbadd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dbadd_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_dbadd_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dbadd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dbadd_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_dbadd_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_dbadd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dbadd_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_dbadd_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_dbadd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dbadd_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_dbadd_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_dbadd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dbadd_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_dbadd_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_dbadd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dbadd_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_dbadd_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_dbadd_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_dbadd_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_dbadd_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_dbadd_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_dbadd_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_dbadd_row11_col1" class="data row11 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_dbadd_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_dbadd_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_dbadd_row12_col1" class="data row12 col1" >03dd</td>
#     </tr>
#   </tbody>
# </table>
#      sepal_length  sepal_width  petal_length  petal_width  Anomaly  \
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        0
# 146           6.3          2.5           5.0          1.9        0
# 147           6.5          3.0           5.2          2.0        0
# 148           6.2          3.4           5.4          2.3        0
# 149           5.9          3.0           5.1          1.8        0
#
#      Anomaly_Score
# 0      -556.251421
# 1      -400.000928
# 2       -93.421993
# 3       -99.229221
# 4       -82.176201
# ..             ...
# 145     -13.831461
# 146      -9.110201
# 147     -20.571707
# 148      -6.345400
# 149     -28.205616
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Data IRIS clean
#
# Data Tanpa Outliers

# %%
clean_iris_abod = df_abod[df_abod["Anomaly"] == 0].merge(iris_df["species"], left_index=True, right_index=True)[["sepal_length", "sepal_width", "petal_length", "petal_width", "species"]]
clean_iris_abod
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [142 rows x 5 columns]

# %% [markdown]
# ### Menyimpan File CSV
#
# Download Hasil: [Download data abod_iris_clean.csv](abod_iris_clean.csv)

# %%
clean_iris_abod.to_csv("abod_iris_clean.csv")

# %% [markdown]
# ## Model KNN
#
# Membuat model KNN dengan fraction (proporsi data yang akan di anggap sebagai outlier) sama dengan 0.05 atau 5%

# %%
from pycaret.anomaly import *

s = setup(data=numeric_iris_df)

iforest_model = create_model("knn", fraction=0.05)

df_knn = assign_model(iforest_model)

df_knn
# Out:
# <style type="text/css">
# #T_6f9bc_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6f9bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f9bc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6f9bc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f9bc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f9bc_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6f9bc_row0_col1" class="data row0 col1" >5315</td>
#     </tr>
#     <tr>
#       <th id="T_6f9bc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6f9bc_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_6f9bc_row1_col1" class="data row1 col1" >(150, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_6f9bc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6f9bc_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_6f9bc_row2_col1" class="data row2 col1" >(150, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_6f9bc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6f9bc_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_6f9bc_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6f9bc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6f9bc_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_6f9bc_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6f9bc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6f9bc_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_6f9bc_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_6f9bc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6f9bc_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_6f9bc_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_6f9bc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6f9bc_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_6f9bc_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_6f9bc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6f9bc_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_6f9bc_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6f9bc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6f9bc_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_6f9bc_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6f9bc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6f9bc_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_6f9bc_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6f9bc_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6f9bc_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_6f9bc_row11_col1" class="data row11 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_6f9bc_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6f9bc_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_6f9bc_row12_col1" class="data row12 col1" >7446</td>
#     </tr>
#   </tbody>
# </table>
#      sepal_length  sepal_width  petal_length  petal_width  Anomaly  \
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        0
# 146           6.3          2.5           5.0          1.9        0
# 147           6.5          3.0           5.2          2.0        0
# 148           6.2          3.4           5.4          2.3        0
# 149           5.9          3.0           5.1          1.8        0
#
#      Anomaly_Score
# 0         0.141421
# 1         0.173205
# 2         0.264575
# 3         0.264575
# 4         0.244949
# ..             ...
# 145       0.374166
# 146       0.479583
# 147       0.387298
# 148       0.624500
# 149       0.360555
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Data IRIS Clean
#
# Data Tanpa Outliers

# %%
clean_iris_knn = df_knn[df_knn["Anomaly"] == 0].merge(iris_df["species"], left_index=True, right_index=True)[["sepal_length", "sepal_width", "petal_length", "petal_width", "species"]]
clean_iris_knn
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [142 rows x 5 columns]

# %% [markdown]
# ### Menyimpan File CSV
#
# Download Hasil: [Download data knn_iris_clean.csv](knn_iris_clean.csv)

# %%
clean_iris_knn.to_csv("knn_iris_clean.csv")

# %% [markdown]
# ## Model LOF
# Membuat model LOF dengan fraction (proporsi data yang akan di anggap sebagai outlier) sama dengan 0.05 atau 5%

# %%
from pycaret.anomaly import *

s = setup(data=numeric_iris_df)

lof_model = create_model("lof", fraction=0.05)

df_lof = assign_model(lof_model)

df_lof
# Out:
# <style type="text/css">
# #T_d1e96_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d1e96">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1e96_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d1e96_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1e96_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d1e96_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d1e96_row0_col1" class="data row0 col1" >5909</td>
#     </tr>
#     <tr>
#       <th id="T_d1e96_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d1e96_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_d1e96_row1_col1" class="data row1 col1" >(150, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_d1e96_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d1e96_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_d1e96_row2_col1" class="data row2 col1" >(150, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_d1e96_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d1e96_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_d1e96_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d1e96_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d1e96_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_d1e96_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d1e96_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d1e96_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_d1e96_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d1e96_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d1e96_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_d1e96_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d1e96_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d1e96_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_d1e96_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d1e96_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d1e96_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_d1e96_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d1e96_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d1e96_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_d1e96_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d1e96_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d1e96_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_d1e96_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d1e96_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d1e96_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_d1e96_row11_col1" class="data row11 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d1e96_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d1e96_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_d1e96_row12_col1" class="data row12 col1" >79eb</td>
#     </tr>
#   </tbody>
# </table>
#      sepal_length  sepal_width  petal_length  petal_width  Anomaly  \
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        0
# 146           6.3          2.5           5.0          1.9        0
# 147           6.5          3.0           5.2          2.0        0
# 148           6.2          3.4           5.4          2.3        0
# 149           5.9          3.0           5.1          1.8        0
#
#      Anomaly_Score
# 0         0.976302
# 1         1.008758
# 2         1.019841
# 3         1.049882
# 4         0.958473
# ..             ...
# 145       0.978474
# 146       1.004232
# 147       0.980847
# 148       1.021819
# 149       1.011326
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Data IRIS clean
#
# Data Tanpa Outliers

# %%
clean_iris_lof = df_lof[df_lof["Anomaly"] == 0].merge(iris_df["species"], left_index=True, right_index=True)[["sepal_length", "sepal_width", "petal_length", "petal_width", "species"]]
clean_iris_lof
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [142 rows x 5 columns]

# %% [markdown]
# ### Menyimpan File CSV
#
# Download Hasil: [Download data lof_iris_clean.csv](lof_iris_clean.csv)

# %%
clean_iris_lof.to_csv("lof_iris_clean.csv")
