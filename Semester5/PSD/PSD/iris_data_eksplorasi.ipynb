# %% [markdown]
# # Data Ekplorasi

# %% [markdown]
# # Missing Value

# %%
import pandas as pd
from module.dataTransformer import combineData
from module.fetcher import fetchDataMysql, fetchDataPg

data_pg = fetchDataPg("SELECT petal_length, petal_width, species FROM iris_table")
data_my = fetchDataMysql("SELECT sepal_length, sepal_width FROM iris_table")

iris_df = combineData(data1=data_my, data2=data_pg)

print("Missing Value:", iris_df.isnull().sum(), end="\n")
# Out:
# Missing Value: sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# ## Outlier

# %% [markdown]
# #### Mengecualikan kolom species

# %%
numeric_iris_data = iris_df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].astype(float)
numeric_iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ### Outliers Detection Dengan (ABOD)
#
# ABOD adalah metode yang sangat berguna untuk mendeteksi outlier dalam data berdimensi tinggi. Ide utamanya adalah bahwa titik data normal membentuk berbagai macam sudut dengan tetangganya, sedangkan outlier cenderung membentuk sudut yang lebih kecil dan konsisten dengan titik-titik lain. Hal ini karena outlier berada di "ujung" atau pinggiran data, sehingga sudut yang terbentuk antara sebuah outlier dengan dua titik lainnya akan sangat sempit.
#
# Langkah Langkah:
# 1. hitung seluruh vektor dari titik pi ke titik lainya
# $\vec{v}_{ij} = p_j - p_i$
# 2. hitung sudut pasangan vector
# $\cos(\theta_{ijk})=\frac{\vec{v}_{ij}\cdot\vec{v}_{ik}}{\|\vec{v}_{ij}\|\cdot\|\vec{v}_{ik}\|}$
# 3. Varian Suduh
# $\text{ABOD}(p_i)=\text{Var}(\theta_{ijk})\quad\text{untuk semua }j,k\neq i$
#
# Titik dengan Varian tertinggi adalah Outlier

# %% [markdown]
# #### Menyiapkan model (ABOD)

# %%
from pycaret.anomaly import *

# %%
from pycaret.anomaly import *

s = setup(data=numeric_iris_data)

abod_model = create_model("abod", fraction=0.05)

df_abod = assign_model(abod_model)
# Out:
# <style type="text/css">
# #T_6dc1e_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6dc1e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6dc1e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6dc1e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6dc1e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6dc1e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6dc1e_row0_col1" class="data row0 col1" >4730</td>
#     </tr>
#     <tr>
#       <th id="T_6dc1e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6dc1e_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_6dc1e_row1_col1" class="data row1 col1" >(150, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_6dc1e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6dc1e_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_6dc1e_row2_col1" class="data row2 col1" >(150, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_6dc1e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6dc1e_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_6dc1e_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6dc1e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6dc1e_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_6dc1e_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6dc1e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6dc1e_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_6dc1e_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_6dc1e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6dc1e_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_6dc1e_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_6dc1e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6dc1e_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_6dc1e_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_6dc1e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6dc1e_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_6dc1e_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6dc1e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6dc1e_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_6dc1e_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6dc1e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6dc1e_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_6dc1e_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6dc1e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6dc1e_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_6dc1e_row11_col1" class="data row11 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_6dc1e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6dc1e_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_6dc1e_row12_col1" class="data row12 col1" >a5de</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Data di anggap Outliers

# %%
outliers = df_abod[df_abod["Anomaly"] == 1]
print(outliers.shape)
outliers
# Out:
# (8, 6)
#      sepal_length  sepal_width  petal_length  petal_width  Anomaly  \
# 41            4.5          2.3           1.3          0.3        1
# 62            6.0          2.2           4.0          1.0        1
# 100           6.3          3.3           6.0          2.5        1
# 106           4.9          2.5           4.5          1.7        1
# 108           6.7          2.5           5.8          1.8        1
# 117           7.7          3.8           6.7          2.2        1
# 131           7.9          3.8           6.4          2.0        1
# 134           6.1          2.6           5.6          1.4        1
#
#      Anomaly_Score
# 41       -0.088998
# 62       -0.289391
# 100      -0.364475
# 106      -0.050388
# 108      -0.084224
# 117      -0.129286
# 131      -0.137417
# 134      -0.309969

# %% [markdown]
# #### Dataframe ABOD
#
# jika nilai Anomaly 1 menunjukan data sebagai outlier

# %%
iris_abod = df_abod.merge(iris_df["species"], left_index=True, right_index=True)

iris_abod
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Anomaly  \
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        0
# 146           6.3          2.5           5.0          1.9        0
# 147           6.5          3.0           5.2          2.0        0
# 148           6.2          3.4           5.4          2.3        0
# 149           5.9          3.0           5.1          1.8        0
#
#      Anomaly_Score         species
# 0      -556.251421     Iris-setosa
# 1      -400.000928     Iris-setosa
# 2       -93.421993     Iris-setosa
# 3       -99.229221     Iris-setosa
# 4       -82.176201     Iris-setosa
# ..             ...             ...
# 145     -13.831461  Iris-virginica
# 146      -9.110201  Iris-virginica
# 147     -20.571707  Iris-virginica
# 148      -6.345400  Iris-virginica
# 149     -28.205616  Iris-virginica
#
# [150 rows x 7 columns]

# %% [markdown]
# ```python
# plot_model(abod_model, plot = 'tsne')
# ```
#
#
# !["3D Plot"](i3d_plot_abod.png)

# %% [markdown]
# ### Outliers Detection Dengan (KNN)
#
# Metode ini adalah salah satu yang paling sederhana dan intuitif untuk deteksi outlier. Pendekatan ini didasarkan pada asumsi bahwa outlier adalah titik data yang letaknya jauh dari sebagian besar titik lainnya. Untuk mendeteksinya, algoritma KNN mengukur jarak dari sebuah titik ke k tetangga terdekatnya. Jika jarak rata-rata ke tetangga-tetangga tersebut sangat besar, titik itu dianggap sebagai outlier.
#
# Langkah Langkah:
# 1. Tentukan Nilai K
# 2. Hitung jarak titik xi ke titik lain menggunakan **Euclidean Distance** dan ambil K jarak terkecil
# $d(x_i,x_j)=\sqrt{\sum_{k=1}^{n}(x_{ik}-x_{jk})^2}$
# 3. hitung KNN distance
# $\text{KNN-Distance}(x_i)=\text{rata-rata jarak ke K tetangga terdekat}$
# Titik dengan KNN-Distance tertinggi dianggap anomali.

# %% [markdown]
# #### Menyiapkan Model KNN

# %%
s = setup(data=numeric_iris_data)
knn_model = create_model('knn', fraction=0.05)
knn_df = assign_model(knn_model)
# Out:
# <style type="text/css">
# #T_251c5_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_251c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_251c5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_251c5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_251c5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_251c5_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_251c5_row0_col1" class="data row0 col1" >5332</td>
#     </tr>
#     <tr>
#       <th id="T_251c5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_251c5_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_251c5_row1_col1" class="data row1 col1" >(150, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_251c5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_251c5_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_251c5_row2_col1" class="data row2 col1" >(150, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_251c5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_251c5_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_251c5_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_251c5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_251c5_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_251c5_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_251c5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_251c5_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_251c5_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_251c5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_251c5_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_251c5_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_251c5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_251c5_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_251c5_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_251c5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_251c5_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_251c5_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_251c5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_251c5_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_251c5_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_251c5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_251c5_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_251c5_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_251c5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_251c5_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_251c5_row11_col1" class="data row11 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_251c5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_251c5_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_251c5_row12_col1" class="data row12 col1" >87a3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Data Dianggap Outlier

# %%
outliers = knn_df[knn_df["Anomaly"] == 1]
print(outliers.shape)
outliers
# Out:
# (8, 6)
#      sepal_length  sepal_width  petal_length  petal_width  Anomaly  \
# 41            4.5          2.3           1.3          0.3        1
# 57            4.9          2.4           3.3          1.0        1
# 98            5.1          2.5           3.0          1.1        1
# 106           4.9          2.5           4.5          1.7        1
# 109           7.2          3.6           6.1          2.5        1
# 117           7.7          3.8           6.7          2.2        1
# 118           7.7          2.6           6.9          2.3        1
# 131           7.9          3.8           6.4          2.0        1
#
#      Anomaly_Score
# 41        0.793726
# 57        0.787401
# 98        0.818535
# 106       0.883176
# 109       0.806226
# 117       1.019804
# 118       0.964365
# 131       1.024695

# %% [markdown]
# #### Dataframe knn

# %%
knn_df = knn_df.merge(iris_df["species"], left_index=True, right_index=True)
knn_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Anomaly  \
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        0
# 146           6.3          2.5           5.0          1.9        0
# 147           6.5          3.0           5.2          2.0        0
# 148           6.2          3.4           5.4          2.3        0
# 149           5.9          3.0           5.1          1.8        0
#
#      Anomaly_Score         species
# 0         0.141421     Iris-setosa
# 1         0.173205     Iris-setosa
# 2         0.264575     Iris-setosa
# 3         0.264575     Iris-setosa
# 4         0.244949     Iris-setosa
# ..             ...             ...
# 145       0.374166  Iris-virginica
# 146       0.479583  Iris-virginica
# 147       0.387298  Iris-virginica
# 148       0.624500  Iris-virginica
# 149       0.360555  Iris-virginica
#
# [150 rows x 7 columns]

# %% [markdown]
# ```python
# plot_model(knn_model, plot = 'tsne')
# ```
#
# ![plot outlier](i3d_plot_iforest.png)

# %% [markdown]
# ### Outliers Detection dengan (LOF)
#
# LOF mengatasi keterbatasan KNN dengan memperkenalkan konsep kepadatan lokal. Alih-alih hanya mengandalkan jarak, LOF membandingkan kepadatan sebuah titik dengan kepadatan tetangganya. Titik data dianggap sebagai outlier jika kepadatan di sekitarnya secara signifikan lebih rendah daripada kepadatan di sekitar tetangga-tetangganya.
#
# Langkah Langkah:
# 1. Tentukan Nilai K
# 2. Hitung jarak titik xi ke titik lain menggunakan **Euclidean Distance** dan ambil K jarak terkecil
# $d(x_i,x_j)=\sqrt{\sum_{k=1}^{n}(x_{ik}-x_{jk})^2}$
# 3. Hitung reachability distance dari titik A ke titik B:
# $\text{reach-dist}_k(A,B)=\max(\text{k-distance}(B),d(A,B))$
# 4. Hitung local reachability density (lrd) dari titik A:
# $\text{lrd}_k(A)=\frac{1}{\frac{\sum_{B \in N_k(A)} \text{reach-dist}_k(A,B)}{|N_k(A)|}}$
# 5. Hitung LOF score dari titik A:
# $\text{LOF}_k(A)=\frac{\sum_{B \in N_k(A)} \frac{\text{lrd}_k(B)}{\text{lrd}_k(A)}}{|N_k(A)|}$
#
# Interpretasi LOF:
# - LOF ≈ 1: kerapatan mirip tetangga → normal
# - LOF >> 1: kerapatan jauh lebih rendah → anomali
# - LOF << 1: lebih padat daripada tetangga → kemungkinan cluster dalam

# %% [markdown]
# #### Menyiapkan model LOF

# %%
s = setup(data=numeric_iris_data)
lof_model = create_model("lof", fraction=0.05)

lof_df = assign_model(lof_model)
# Out:
# <style type="text/css">
# #T_946f8_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_946f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_946f8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_946f8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_946f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_946f8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_946f8_row0_col1" class="data row0 col1" >3977</td>
#     </tr>
#     <tr>
#       <th id="T_946f8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_946f8_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_946f8_row1_col1" class="data row1 col1" >(150, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_946f8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_946f8_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_946f8_row2_col1" class="data row2 col1" >(150, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_946f8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_946f8_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_946f8_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_946f8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_946f8_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_946f8_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_946f8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_946f8_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_946f8_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_946f8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_946f8_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_946f8_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_946f8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_946f8_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_946f8_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_946f8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_946f8_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_946f8_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_946f8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_946f8_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_946f8_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_946f8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_946f8_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_946f8_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_946f8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_946f8_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_946f8_row11_col1" class="data row11 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_946f8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_946f8_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_946f8_row12_col1" class="data row12 col1" >e57b</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Data Outliers

# %%
outliers = lof_df[lof_df["Anomaly"] == 1]
print(outliers.shape)
outliers
# Out:
# (8, 6)
#      sepal_length  sepal_width  petal_length  petal_width  Anomaly  \
# 14            5.8          4.0           1.2          0.2        1
# 15            5.7          4.4           1.5          0.4        1
# 41            4.5          2.3           1.3          0.3        1
# 98            5.1          2.5           3.0          1.1        1
# 117           7.7          3.8           6.7          2.2        1
# 118           7.7          2.6           6.9          2.3        1
# 122           7.7          2.8           6.7          2.0        1
# 131           7.9          3.8           6.4          2.0        1
#
#      Anomaly_Score
# 14        1.463125
# 15        1.653626
# 41        1.777233
# 98        1.511868
# 117       1.572990
# 118       1.624653
# 122       1.491365
# 131       1.547288

# %% [markdown]
# #### lof Dataframe

# %%
lof_df = lof_df.merge(iris_df["species"], left_index=True, right_index=True)
lof_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Anomaly  \
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        0
# 146           6.3          2.5           5.0          1.9        0
# 147           6.5          3.0           5.2          2.0        0
# 148           6.2          3.4           5.4          2.3        0
# 149           5.9          3.0           5.1          1.8        0
#
#      Anomaly_Score         species
# 0         0.976302     Iris-setosa
# 1         1.008758     Iris-setosa
# 2         1.019841     Iris-setosa
# 3         1.049882     Iris-setosa
# 4         0.958473     Iris-setosa
# ..             ...             ...
# 145       0.978474  Iris-virginica
# 146       1.004232  Iris-virginica
# 147       0.980847  Iris-virginica
# 148       1.021819  Iris-virginica
# 149       1.011326  Iris-virginica
#
# [150 rows x 7 columns]

# %% [markdown]
# ```python
# plot_model(lof_model, plot='tsne')
# ```
#
# ![plot outlier](i3d_plot_lof.png)

# %% [markdown]
# ## Min, Max dan Average Setiap Kolom
#
# Tabel berikut menampilkan nilai **maksimum (Max Value)**, **minimum (Min Value)**, dan **rata-rata (Average Value)** dari setiap fitur pada dataset Iris:
#
# ![Min, Max Average Setiap Kolom](iris_min_ma.png)
#
# ### Interpretasi
# - **Petal Length** memiliki rentang yang cukup lebar (1.00 – 6.90) dengan rata-rata 3.76.
# - **Petal Width** bervariasi dari 0.10 hingga 2.50, dengan rata-rata 1.20.
# - **Sepal Length** memiliki nilai rata-rata paling tinggi (5.84) dibandingkan fitur lain.
# - **Sepal Width** berada pada kisaran 2.00 – 4.40 dengan rata-rata 3.05.
#
# Dari ringkasan statistik ini dapat dilihat bahwa **petal** memiliki variasi lebih besar dibandingkan **sepal**, sehingga kemungkinan besar akan berperan penting dalam membedakan kelas spesies bunga Iris.

# %% [markdown]
# ## Distribusi Kelas
#
# Visualisasi berikut menunjukkan jumlah data pada masing-masing kelas:
#
# - **Iris-setosa**: 50 data
# - **Iris-versicolor**: 50 data
# - **Iris-virginica**: 50 data
#
# Total dataset terdiri dari **150 data** yang terbagi **seimbang** antar ketiga kelas.
#
# ![Distribusi Kelas](new_species.png)
#
# **Interpretasi:**
# - Dataset **seimbang (balanced)** karena setiap kelas memiliki jumlah data yang sama.
# - Hal ini menguntungkan untuk proses klasifikasi, karena model tidak akan bias terhadap salah satu kelas.
